# %% [markdown]
# # Model used COVID19_HumanChallenge_Blood--done

# %%
import os
root_dir = "/dss/dsshome1/02/di93zoj/shahana"
import anndata
import numpy as np
import pandas as pd
from scipy.sparse import csr_matrix
import scanpy as sc
import h5py

# %%
#!python -m pip install --upgrade pip

# %%
# !pip install celltypist
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting celltypist
#   Obtaining dependency information for celltypist from https://files.pythonhosted.org/packages/12/95/654d51b08e4da729577363c4692d29cd2d278e8aa3417d79195de949cadb/celltypist-1.6.2-py3-none-any.whl.metadata
#   Downloading celltypist-1.6.2-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19.0 in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from celltypist) (1.23.5)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.8/dist-packages (from celltypist) (1.5.2)
# Requirement already satisfied: scikit-learn>=0.24.1 in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from celltypist) (1.2.2)
# Requirement already satisfied: openpyxl>=3.0.4 in /usr/local/lib/python3.8/dist-packages (from celltypist) (3.1.2)
# Requirement already satisfied: click>=7.1.2 in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from celltypist) (8.1.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.8/dist-packages (from celltypist) (2.28.2)
# Requirement already satisfied: scanpy>=1.7.0 in /usr/local/lib/python3.8/dist-packages (from celltypist) (1.9.5)
# Requirement already satisfied: leidenalg>=0.9.0 in /usr/local/lib/python3.8/dist-packages (from celltypist) (0.9.1)
# Requirement already satisfied: igraph<0.11,>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from leidenalg>=0.9.0->celltypist) (0.10.8)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.8/dist-packages (from openpyxl>=3.0.4->celltypist) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from pandas>=1.0.5->celltypist) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from pandas>=1.0.5->celltypist) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from requests>=2.23.0->celltypist) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from requests>=2.23.0->celltypist) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.23.0->celltypist) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.23.0->celltypist) (2022.12.7)
# Requirement already satisfied: anndata>=0.7.4 in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from scanpy>=1.7.0->celltypist) (0.8.0)
# Requirement already satisfied: matplotlib>=3.4 in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from scanpy>=1.7.0->celltypist) (3.7.1)
# Requirement already satisfied: scipy>=1.4 in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from scanpy>=1.7.0->celltypist) (1.10.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.8/dist-packages (from scanpy>=1.7.0->celltypist) (0.11.2)
# Requirement already satisfied: h5py>=3 in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from scanpy>=1.7.0->celltypist) (3.8.0)
# Requirement already satisfied: tqdm in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from scanpy>=1.7.0->celltypist) (4.65.0)
# Requirement already satisfied: statsmodels>=0.10.0rc2 in /usr/local/lib/python3.8/dist-packages (from scanpy>=1.7.0->celltypist) (0.14.0)
# Requirement already satisfied: patsy in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from scanpy>=1.7.0->celltypist) (0.5.3)
# Requirement already satisfied: networkx>=2.3 in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from scanpy>=1.7.0->celltypist) (3.0)
# Requirement already satisfied: natsort in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from scanpy>=1.7.0->celltypist) (8.3.1)
# Requirement already satisfied: joblib in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from scanpy>=1.7.0->celltypist) (1.2.0)
# Requirement already satisfied: numba>=0.41.0 in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from scanpy>=1.7.0->celltypist) (0.56.4)
# Requirement already satisfied: umap-learn>=0.3.10 in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from scanpy>=1.7.0->celltypist) (0.5.3)
# Requirement already satisfied: packaging in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from scanpy>=1.7.0->celltypist) (23.0)
# Requirement already satisfied: session-info in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from scanpy>=1.7.0->celltypist) (1.0.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from scikit-learn>=0.24.1->celltypist) (3.1.0)
# Requirement already satisfied: texttable>=1.6.2 in /usr/local/lib/python3.8/dist-packages (from igraph<0.11,>=0.10.0->leidenalg>=0.9.0->celltypist) (1.6.7)
# Requirement already satisfied: contourpy>=1.0.1 in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from matplotlib>=3.4->scanpy>=1.7.0->celltypist) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from matplotlib>=3.4->scanpy>=1.7.0->celltypist) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from matplotlib>=3.4->scanpy>=1.7.0->celltypist) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from matplotlib>=3.4->scanpy>=1.7.0->celltypist) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.4->scanpy>=1.7.0->celltypist) (9.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from matplotlib>=3.4->scanpy>=1.7.0->celltypist) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from matplotlib>=3.4->scanpy>=1.7.0->celltypist) (5.12.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from numba>=0.41.0->scanpy>=1.7.0->celltypist) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from numba>=0.41.0->scanpy>=1.7.0->celltypist) (65.5.1)
# Requirement already satisfied: importlib-metadata in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from numba>=0.41.0->scanpy>=1.7.0->celltypist) (6.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.8.1->pandas>=1.0.5->celltypist) (1.16.0)
# Requirement already satisfied: pynndescent>=0.5 in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from umap-learn>=0.3.10->scanpy>=1.7.0->celltypist) (0.5.8)
# Requirement already satisfied: stdlib_list in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from session-info->scanpy>=1.7.0->celltypist) (0.8.0)
# Requirement already satisfied: zipp>=3.1.0 in /dss/dsshome1/02/di93zoj/.local/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.4->scanpy>=1.7.0->celltypist) (3.15.0)
# Downloading celltypist-1.6.2-py3-none-any.whl (7.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 4.5 MB/s eta 0:00:0000:0100:01
# DEPRECATION: cudf 23.2.0 has a non-standard dependency specifier cuda-python>=12.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of cudf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# DEPRECATION: pylibraft 23.2.0 has a non-standard dependency specifier cuda-python>=12.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pylibraft or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# DEPRECATION: pytorch-lightning 1.7.7 has a non-standard dependency specifier torch>=1.9.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# DEPRECATION: rmm 23.2.0 has a non-standard dependency specifier cuda-python>=12.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of rmm or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: celltypist
# Successfully installed celltypist-1.6.2
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python -m pip install --upgrade pip

# %%
import celltypist
from celltypist import models

# %% [markdown]
# Assign cell type labels using a CellTypist built-in model

# %%
# Enabling `force_update = True` will overwrite existing (old) models.
models.download_models(force_update = True)
# Out:
# 📜 Retrieving model list from server https://celltypist.cog.sanger.ac.uk/models/models.json
# 📚 Total models in list: 44
# 📂 Storing models in /dss/dsshome1/02/di93zoj/.celltypist/data/models
# 💾 Downloading model [1/44]: Immune_All_Low.pkl
# 💾 Downloading model [2/44]: Immune_All_High.pkl
# 💾 Downloading model [3/44]: Adult_CynomolgusMacaque_Hippocampus.pkl
# 💾 Downloading model [4/44]: Adult_Human_PancreaticIslet.pkl
# 💾 Downloading model [5/44]: Adult_Human_Skin.pkl
# 💾 Downloading model [6/44]: Adult_Mouse_Gut.pkl
# 💾 Downloading model [7/44]: Adult_Mouse_OlfactoryBulb.pkl
# 💾 Downloading model [8/44]: Adult_Pig_Hippocampus.pkl
# 💾 Downloading model [9/44]: Adult_RhesusMacaque_Hippocampus.pkl
# 💾 Downloading model [10/44]: Autopsy_COVID19_Lung.pkl
# 💾 Downloading model [11/44]: COVID19_HumanChallenge_Blood.pkl
# 💾 Downloading model [12/44]: COVID19_Immune_Landscape.pkl
# 💾 Downloading model [13/44]: Cells_Fetal_Lung.pkl
# 💾 Downloading model [14/44]: Cells_Intestinal_Tract.pkl
# 💾 Downloading model [15/44]: Cells_Lung_Airway.pkl
# 💾 Downloading model [16/44]: Developing_Human_Brain.pkl
# 💾 Downloading model [17/44]: Developing_Human_Gonads.pkl
# 💾 Downloading model [18/44]: Developing_Human_Hippocampus.pkl
# 💾 Downloading model [19/44]: Developing_Human_Organs.pkl
# 💾 Downloading model [20/44]: Developing_Human_Thymus.pkl
# 💾 Downloading model [21/44]: Developing_Mouse_Brain.pkl
# 💾 Downloading model [22/44]: Developing_Mouse_Hippocampus.pkl
# 💾 Downloading model [23/44]: Fetal_Human_AdrenalGlands.pkl
# 💾 Downloading model [24/44]: Fetal_Human_Pancreas.pkl
# 💾 Downloading model [25/44]: Fetal_Human_Pituitary.pkl
# 💾 Downloading model [26/44]: Fetal_Human_Retina.pkl
# 💾 Downloading model [27/44]: Fetal_Human_Skin.pkl
# 💾 Downloading model [28/44]: Healthy_Adult_Heart.pkl
# 💾 Downloading model [29/44]: Healthy_COVID19_PBMC.pkl
# 💾 Downloading model [30/44]: Healthy_Human_Liver.pkl
# 💾 Downloading model [31/44]: Healthy_Mouse_Liver.pkl
# 💾 Downloading model [32/44]: Human_AdultAged_Hippocampus.pkl
# 💾 Downloading model [33/44]: Human_Developmental_Retina.pkl
# 💾 Downloading model [34/44]: Human_Embryonic_YolkSac.pkl
# 💾 Downloading model [35/44]: Human_IPF_Lung.pkl
# 💾 Downloading model [36/44]: Human_Longitudinal_Hippocampus.pkl
# 💾 Downloading model [37/44]: Human_Lung_Atlas.pkl
# 💾 Downloading model [38/44]: Human_PF_Lung.pkl
# 💾 Downloading model [39/44]: Lethal_COVID19_Lung.pkl
# 💾 Downloading model [40/44]: Mouse_Dentate_Gyrus.pkl
# 💾 Downloading model [41/44]: Mouse_Isocortex_Hippocampus.pkl
# 💾 Downloading model [42/44]: Mouse_Postnatal_DentateGyrus.pkl
# 💾 Downloading model [43/44]: Nuclei_Lung_Airway.pkl
# 💾 Downloading model [44/44]: Pan_Fetal_Human.pkl

# %%
models.models_path
# Out:
# '/dss/dsshome1/02/di93zoj/.celltypist/data/models'

# %%
models.models_description()
# Out:
# 👉 Detailed model information can be found at `https://www.celltypist.org/models`
#                                       model  \
# 0                        Immune_All_Low.pkl
# 1                       Immune_All_High.pkl
# 2   Adult_CynomolgusMacaque_Hippocampus.pkl
# 3           Adult_Human_PancreaticIslet.pkl
# 4                      Adult_Human_Skin.pkl
# 5                       Adult_Mouse_Gut.pkl
# 6             Adult_Mouse_OlfactoryBulb.pkl
# 7                 Adult_Pig_Hippocampus.pkl
# 8       Adult_RhesusMacaque_Hippocampus.pkl
# 9                  Autopsy_COVID19_Lung.pkl
# 10         COVID19_HumanChallenge_Blood.pkl
# 11             COVID19_Immune_Landscape.pkl
# 12                     Cells_Fetal_Lung.pkl
# 13               Cells_Intestinal_Tract.pkl
# 14                    Cells_Lung_Airway.pkl
# 15               Developing_Human_Brain.pkl
# 16              Developing_Human_Gonads.pkl
# 17         Developing_Human_Hippocampus.pkl
# 18              Developing_Human_Organs.pkl
# 19              Developing_Human_Thymus.pkl
# 20               Developing_Mouse_Brain.pkl
# 21         Developing_Mouse_Hippocampus.pkl
# 22            Fetal_Human_AdrenalGlands.pkl
# 23                 Fetal_Human_Pancreas.pkl
# 24                Fetal_Human_Pituitary.pkl
# 25                   Fetal_Human_Retina.pkl
# 26                     Fetal_Human_Skin.pkl
# 27                  Healthy_Adult_Heart.pkl
# 28                 Healthy_COVID19_PBMC.pkl
# 29                  Healthy_Human_Liver.pkl
# 30                  Healthy_Mouse_Liver.pkl
# 31          Human_AdultAged_Hippocampus.pkl
# 32           Human_Developmental_Retina.pkl
# 33              Human_Embryonic_YolkSac.pkl
# 34                       Human_IPF_Lung.pkl
# 35       Human_Longitudinal_Hippocampus.pkl
# 36                     Human_Lung_Atlas.pkl
# 37                        Human_PF_Lung.pkl
# 38                  Lethal_COVID19_Lung.pkl
# 39                  Mouse_Dentate_Gyrus.pkl
# 40          Mouse_Isocortex_Hippocampus.pkl
# 41         Mouse_Postnatal_DentateGyrus.pkl
# 42                   Nuclei_Lung_Airway.pkl
# 43                      Pan_Fetal_Human.pkl
#
#                                           description
# 0   immune sub-populations combined from 20 tissue...
# 1   immune populations combined from 20 tissues of...
# 2   cell types from the hippocampus of adult cynom...
# 3   cell types from pancreatic islets of healthy a...
# 4            cell types from human healthy adult skin
# 5   cell types in the adult mouse gut combined fro...
# 6    cell types from the olfactory bulb of adult mice
# 7           cell types from the adult pig hippocampus
# 8   cell types from the hippocampus of adult rhesu...
# 9   cell types from the lungs of 16 SARS-CoV-2 inf...
# 10  detailed blood cell states from 16 individuals...
# 11  immune subtypes from lung and blood of COVID-1...
# 12    cell types from human embryonic and fetal lungs
# 13  intestinal cells from fetal, pediatric (health...
# 14  cell populations from scRNA-seq of five locati...
# 15  cell types from the first-trimester developing...
# 16  cell types of human gonadal and adjacent extra...
# 17   cell types from the developing human hippocampus
# 18  cell types of five endoderm-derived organs in ...
# 19  cell populations in embryonic, fetal, pediatri...
# 20  cell types from the embryonic mouse brain betw...
# 21  cell types from the mouse hippocampus at postn...
# 22  cell types of human fetal adrenal glands from ...
# 23  pancreatic cell types from human embryos at 9-...
# 24  cell types of human fetal pituitaries from 7 t...
# 25  cell types from human fetal neural retina and ...
# 26        cell types from developing human fetal skin
# 27  cell types from eight anatomical regions of th...
# 28  peripheral blood mononuclear cell types from h...
# 29  cell types from scRNA-seq and snRNA-seq of the...
# 30  cell types from scRNA-seq and snRNA-seq of the...
# 31  cell types from the hippocampus of adult and a...
# 32                 cell types from human fetal retina
# 33  cell types of the human yolk sac from 4-8 post...
# 34  cell types from idiopathic pulmonary fibrosis,...
# 35  cell types from the adult human anterior and p...
# 36  integrated Human Lung Cell Atlas (HLCA) combin...
# 37  cell types from different forms of pulmonary f...
# 38  cell types from the lungs of individuals who d...
# 39  cell types from the dentate gyrus in perinatal...
# 40  cell types from the adult mouse isocortex (neo...
# 41  cell types from the mouse dentate gyrus in pos...
# 42  cell populations from snRNA-seq of five locati...
# 43  stromal and immune populations from the human ...

# %%
# Indeed, the `model` argument defaults to `Immune_All_Low.pkl`.
model = models.Model.load(model = 'COVID19_HumanChallenge_Blood.pkl')

# %% [markdown]
# Show model meta information

# %%
model
# Out:
# CellTypist model with 83 cell types and 4310 features
#     date: 2022-09-29 17:40:05.907115
#     details: detailed blood cell states from 16 individuals after being challenged with SARS-CoV-2
#     source: TBD
#     version: v1
#     cell types: AS-DC, B Naive, ..., pDC IFN stim
#     features: HES4, ISG15, ..., MT-CYB

# %%
model.cell_types
# Out:
# array(['AS-DC', 'B Naive', 'B Naive IFN stim', 'B Non-Switched FCRL3+',
#        'B Non-Switched Memory', 'B Non-Switched Memory IFN stim',
#        'B Switched FCRL3+', 'B Switched Memory',
#        'B Switched Memory IFN stim',
#        'Eosinophil/Basophil/Mast Progenitor',
#        'Haematopoietic Progenitor CD34+/CD38+',
#        'Haematopoietic Progenitor CD34+/CD38+ IFN stim',
#        'Haematopoietic Progenitor CD34+/CD38-', 'ILC', 'ILC IFN stim',
#        'Lymphoid Progenitor', 'Monocyte CD14+', 'Monocyte CD14+ IFN stim',
#        'Monocyte CD14+ Pro-inflammatory', 'Monocyte CD16+',
#        'Monocyte CD16+ C1+', 'Monocyte CD16+ IFN stim',
#        'Myeloid Progenitor', 'NK', 'NK CD56+', 'NK CD56+ Cycling',
#        'NK Cycling', 'NK IFN stim', 'NKT', 'Plasma Cell', 'Plasmablast',
#        'T CD4 Activated CTL', 'T CD4 Activated CTL Cycling',
#        'T CD4 Activated Helper 1', 'T CD4 Activated Helper 1 Cycling',
#        'T CD4 CTL', 'T CD4 Follicular Helper', 'T CD4 Helper 0',
#        'T CD4 Helper 0 IFN stim', 'T CD4 Helper 1',
#        'T CD4 Helper 1 IFN stim', 'T CD4 Helper 17', 'T CD4 Helper 2',
#        'T CD4 Helper 2 IFN stim', 'T CD4 Naive', 'T CD4 Naive IFN stim',
#        'T CD4 Naive RTE', 'T CD8 Activated CTL',
#        'T CD8 Activated CTL Cycling', 'T CD8 CM', 'T CD8 CM IFN stim',
#        'T CD8 CTL', 'T CD8 CTL Cycling', 'T CD8 CTL IFN stim', 'T CD8 EM',
#        'T CD8 EMRA', 'T CD8 Naive', 'T CD8 Naive IFN stim',
#        'T CD8 Naive RTE', 'T Double Negative',
#        'T Double Negative Cycling', 'T G/D CM', 'T G/D CM IFN stim',
#        'T G/D EM', 'T G/D Immature', 'T G/D Immature RTE',
#        'T G/D non-Dv2/Gv9', 'T MAI', 'T MAI Activated', 'T Reg Activated',
#        'T Reg Activated Cycling', 'T Reg CM', 'T Reg CM GZMK+ IFNG+',
#        'T Reg EM', 'T Reg EM Cycling', 'cDC1', 'cDC1 Cycling',
#        'cDC1 IFN stim', 'cDC2', 'cDC2 CD14+', 'cDC2 IFN stim', 'pDC',
#        'pDC IFN stim'], dtype=object)

# %%
adata_covid = sc.read('/dss/dsshome1/02/di93zoj/2301_annot_patient_integrated.h5ad')

# %%
adata_covid
# Out:
# AnnData object with n_obs × n_vars = 254630 × 18115
#     obs: 'identifier', 'patient', 'name', 'barcode_round', 'sample', 'viral_counts', 'treatment', 'treatment_virus', 'infected', 'n_counts', 'n_genes', 'percent_mito', 'percent_viral', 'leiden', 'final_bcs', 'batch', 'celltype_coarse', 'cell_type', 'infection_label', '_scvi_batch', '_scvi_labels', 'leiden_coarse', 'leiden_fine', 'leiden_subset', 'celltype_fine', 'celltype_approx'
#     var: 'used_for_scvi'
#     uns: '_scvi', 'celltype_approx_colors', 'celltype_coarse_colors', 'celltype_fine_colors', 'dendrogram_leiden_fine', 'hvg', 'infected_colors', 'leiden', 'leiden_coarse_colors', 'leiden_colors', 'leiden_fine_colors', 'neighbors', 'patient_colors', 'rank_genes_groups', 'treatment_colors', 'umap'
#     obsm: 'X_pca', 'X_scVI', 'X_umap'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
# Not run; predict cell identities using this loaded model.
#predictions = celltypist.annotate(adata_2000, model = model, majority_voting = True)
# Alternatively, just specify the model name (recommended as this ensures the model is intact every time it is loaded).
predictions = celltypist.annotate(adata_covid, model = 'COVID19_HumanChallenge_Blood.pkl', majority_voting = True)
# Out:
# ⚠️ Warning: invalid expression matrix, expect ALL genes and log1p normalized expression to 10000 counts per cell. The prediction result may not be accurate
# 🔬 Input data has 254630 cells and 18115 genes
# 🔗 Matching reference genes in the model
# 🧬 3841 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Detected a neighborhood graph in the input object, will run over-clustering on the basis of it
# ⛓️ Over-clustering input data with resolution set to 30
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!

# %%
# What is this warning at the beginning of the prediction analysis "invalid expression matrix, expect ALL genes and log1p normalized expression to 10000 counts per cell. The prediction result may not be accurate". do I need to modify/more preprocess the covid data?? the

# %%
predictions.predicted_labels
# Out:
#                                                 predicted_labels  \
# muc21058_AAACCCAAGTTTGAGA                               NK CD56+
# muc21058_AAACCCACACGCGCAT  Haematopoietic Progenitor CD34+/CD38-
# muc21058_AAACCCACAGACACAG  Haematopoietic Progenitor CD34+/CD38-
# muc21058_AAACCCAGTATTGCCA                        T CD4 Naive RTE
# muc21058_AAACCCAGTCGTATTG                             T CD8 EMRA
# ...                                                          ...
# muc22968_TTTGTTGCATCACCAA                               T G/D CM
# muc22968_TTTGTTGGTTCCGTTC                         Monocyte CD14+
# muc22968_TTTGTTGTCCACACCT                               T G/D CM
# muc22968_TTTGTTGTCTAACGGT                                  T MAI
# muc22968_TTTGTTGTCTTGGAAC                               T G/D CM
#
#                           over_clustering  \
# muc21058_AAACCCAAGTTTGAGA              18
# muc21058_AAACCCACACGCGCAT              54
# muc21058_AAACCCACAGACACAG              84
# muc21058_AAACCCAGTATTGCCA              27
# muc21058_AAACCCAGTCGTATTG              18
# ...                                   ...
# muc22968_TTTGTTGCATCACCAA             282
# muc22968_TTTGTTGGTTCCGTTC             332
# muc22968_TTTGTTGTCCACACCT             346
# muc22968_TTTGTTGTCTAACGGT              89
# muc22968_TTTGTTGTCTTGGAAC             283
#
#                                                  majority_voting
# muc21058_AAACCCAAGTTTGAGA  Haematopoietic Progenitor CD34+/CD38-
# muc21058_AAACCCACACGCGCAT  Haematopoietic Progenitor CD34+/CD38-
# muc21058_AAACCCACAGACACAG                               T G/D CM
# muc21058_AAACCCAGTATTGCCA  Haematopoietic Progenitor CD34+/CD38-
# muc21058_AAACCCAGTCGTATTG  Haematopoietic Progenitor CD34+/CD38-
# ...                                                          ...
# muc22968_TTTGTTGCATCACCAA                               T G/D CM
# muc22968_TTTGTTGGTTCCGTTC                               T G/D CM
# muc22968_TTTGTTGTCCACACCT                               T G/D CM
# muc22968_TTTGTTGTCTAACGGT                T Reg Activated Cycling
# muc22968_TTTGTTGTCTTGGAAC                            Plasma Cell
#
# [254630 rows x 3 columns]

# %%
# Get an `AnnData` with predicted labels embedded into the cell metadata columns.
adata = predictions.to_adata()

# %%
adata.obs
# Out:
#                           identifier    patient             name  \
# muc21058_AAACCCAAGTTTGAGA   muc21058  patient_1  ALI_1_Barcode_1
# muc21058_AAACCCACACGCGCAT   muc21058  patient_1  ALI_1_Barcode_1
# muc21058_AAACCCACAGACACAG   muc21058  patient_1  ALI_1_Barcode_1
# muc21058_AAACCCAGTATTGCCA   muc21058  patient_1  ALI_1_Barcode_1
# muc21058_AAACCCAGTCGTATTG   muc21058  patient_1  ALI_1_Barcode_1
# ...                              ...        ...              ...
# muc22968_TTTGTTGCATCACCAA   muc22968  patient_4  ALI_3_Barcode_4
# muc22968_TTTGTTGGTTCCGTTC   muc22968  patient_4  ALI_3_Barcode_4
# muc22968_TTTGTTGTCCACACCT   muc22968  patient_4  ALI_3_Barcode_4
# muc22968_TTTGTTGTCTAACGGT   muc22968  patient_4  ALI_3_Barcode_4
# muc22968_TTTGTTGTCTTGGAAC   muc22968  patient_4  ALI_3_Barcode_4
#
#                           barcode_round sample  viral_counts  \
# muc21058_AAACCCAAGTTTGAGA         ALI_1      3           0.0
# muc21058_AAACCCACACGCGCAT         ALI_1      3           0.0
# muc21058_AAACCCACAGACACAG         ALI_1      3           0.0
# muc21058_AAACCCAGTATTGCCA         ALI_1      3           0.0
# muc21058_AAACCCAGTCGTATTG         ALI_1      3           0.0
# ...                                 ...    ...           ...
# muc22968_TTTGTTGCATCACCAA         ALI_3     11           0.0
# muc22968_TTTGTTGGTTCCGTTC         ALI_3     11           0.0
# muc22968_TTTGTTGTCCACACCT         ALI_3     11           0.0
# muc22968_TTTGTTGTCTAACGGT         ALI_3     11           0.0
# muc22968_TTTGTTGTCTTGGAAC         ALI_3     11           0.0
#
#                                     treatment            treatment_virus  \
# muc21058_AAACCCAAGTTTGAGA           TNFa_IFNg     TNFa_IFNg + sars-cov-2
# muc21058_AAACCCACACGCGCAT          IFNa (b_d)                 IFNa (b_d)
# muc21058_AAACCCACAGACACAG                IFNg                       IFNg
# muc21058_AAACCCAGTATTGCCA          IFNa (b_d)    IFNa (b_d) + sars-cov-2
# muc21058_AAACCCAGTCGTATTG        Tirapazamine  Tirapazamine + sars-cov-2
# ...                                       ...                        ...
# muc22968_TTTGTTGCATCACCAA           Sorafenib     Sorafenib + sars-cov-2
# muc22968_TTTGTTGGTTCCGTTC               TGFb2         TGFb2 + sars-cov-2
# muc22968_TTTGTTGTCCACACCT                DMSO          DMSO + sars-cov-2
# muc22968_TTTGTTGTCTAACGGT           Sorafenib     Sorafenib + sars-cov-2
# muc22968_TTTGTTGTCTTGGAAC  TGFb2_Tirapazamine          TGFb_Tirapazamine
#
#                           infected  n_counts  ...  _scvi_labels  \
# muc21058_AAACCCAAGTTTGAGA     True    9775.0  ...             0
# muc21058_AAACCCACACGCGCAT    False   12826.0  ...             0
# muc21058_AAACCCACAGACACAG    False   15557.0  ...             0
# muc21058_AAACCCAGTATTGCCA     True   15520.0  ...             0
# muc21058_AAACCCAGTCGTATTG     True   13483.0  ...             0
# ...                            ...       ...  ...           ...
# muc22968_TTTGTTGCATCACCAA     True   13844.0  ...             0
# muc22968_TTTGTTGGTTCCGTTC     True    2846.0  ...             0
# muc22968_TTTGTTGTCCACACCT     True   10235.0  ...             0
# muc22968_TTTGTTGTCTAACGGT     True   11320.0  ...             0
# muc22968_TTTGTTGTCTTGGAAC    False    6402.0  ...             0
#
#                            leiden_coarse  leiden_fine leiden_subset  \
# muc21058_AAACCCAAGTTTGAGA              3         13,1          13,1
# muc21058_AAACCCACACGCGCAT              4         14,0          14,0
# muc21058_AAACCCACAGACACAG              6           10            10
# muc21058_AAACCCAGTATTGCCA              4         14,0          14,0
# muc21058_AAACCCAGTCGTATTG              4         14,1          14,1
# ...                                  ...          ...           ...
# muc22968_TTTGTTGCATCACCAA              6           15            15
# muc22968_TTTGTTGGTTCCGTTC              6            2             2
# muc22968_TTTGTTGTCCACACCT              6            2             2
# muc22968_TTTGTTGTCTAACGGT             13           16            16
# muc22968_TTTGTTGTCTTGGAAC              0            6             6
#
#                               celltype_fine celltype_approx  \
# muc21058_AAACCCAAGTTTGAGA         sub5/club       13,1/club
# muc21058_AAACCCACACGCGCAT         sub3/club       14,0/club
# muc21058_AAACCCACAGACACAG     10/suprabasal   10/suprabasal
# muc21058_AAACCCAGTATTGCCA         sub3/club       14,0/club
# muc21058_AAACCCAGTCGTATTG         sub3/club       14,1/club
# ...                                     ...             ...
# muc22968_TTTGTTGCATCACCAA     15/suprabasal   15/suprabasal
# muc22968_TTTGTTGGTTCCGTTC      2/suprabasal    2/suprabasal
# muc22968_TTTGTTGTCCACACCT      2/suprabasal    2/suprabasal
# muc22968_TTTGTTGTCTAACGGT  16/basal prolif.   16/suprabasal
# muc22968_TTTGTTGTCTTGGAAC           6/basal         6/basal
#
#                                                 predicted_labels  \
# muc21058_AAACCCAAGTTTGAGA                               NK CD56+
# muc21058_AAACCCACACGCGCAT  Haematopoietic Progenitor CD34+/CD38-
# muc21058_AAACCCACAGACACAG  Haematopoietic Progenitor CD34+/CD38-
# muc21058_AAACCCAGTATTGCCA                        T CD4 Naive RTE
# muc21058_AAACCCAGTCGTATTG                             T CD8 EMRA
# ...                                                          ...
# muc22968_TTTGTTGCATCACCAA                               T G/D CM
# muc22968_TTTGTTGGTTCCGTTC                         Monocyte CD14+
# muc22968_TTTGTTGTCCACACCT                               T G/D CM
# muc22968_TTTGTTGTCTAACGGT                                  T MAI
# muc22968_TTTGTTGTCTTGGAAC                               T G/D CM
#
#                           over_clustering  \
# muc21058_AAACCCAAGTTTGAGA              18
# muc21058_AAACCCACACGCGCAT              54
# muc21058_AAACCCACAGACACAG              84
# muc21058_AAACCCAGTATTGCCA              27
# muc21058_AAACCCAGTCGTATTG              18
# ...                                   ...
# muc22968_TTTGTTGCATCACCAA             282
# muc22968_TTTGTTGGTTCCGTTC             332
# muc22968_TTTGTTGTCCACACCT             346
# muc22968_TTTGTTGTCTAACGGT              89
# muc22968_TTTGTTGTCTTGGAAC             283
#
#                                                  majority_voting  conf_score
# muc21058_AAACCCAAGTTTGAGA  Haematopoietic Progenitor CD34+/CD38-    0.126538
# muc21058_AAACCCACACGCGCAT  Haematopoietic Progenitor CD34+/CD38-    0.847628
# muc21058_AAACCCACAGACACAG                               T G/D CM    0.867448
# muc21058_AAACCCAGTATTGCCA  Haematopoietic Progenitor CD34+/CD38-    0.987700
# muc21058_AAACCCAGTCGTATTG  Haematopoietic Progenitor CD34+/CD38-    0.754063
# ...                                                          ...         ...
# muc22968_TTTGTTGCATCACCAA                               T G/D CM    0.979020
# muc22968_TTTGTTGGTTCCGTTC                               T G/D CM    0.538926
# muc22968_TTTGTTGTCCACACCT                               T G/D CM    0.992821
# muc22968_TTTGTTGTCTAACGGT                T Reg Activated Cycling    0.996122
# muc22968_TTTGTTGTCTTGGAAC                            Plasma Cell    0.996680
#
# [254630 rows x 30 columns]

# %%
adata.obs.cell_type
# Out:
# muc21058_AAACCCAAGTTTGAGA             club
# muc21058_AAACCCACACGCGCAT             club
# muc21058_AAACCCACAGACACAG       suprabasal
# muc21058_AAACCCAGTATTGCCA             club
# muc21058_AAACCCAGTCGTATTG             club
#                                  ...
# muc22968_TTTGTTGCATCACCAA       suprabasal
# muc22968_TTTGTTGGTTCCGTTC       suprabasal
# muc22968_TTTGTTGTCCACACCT       suprabasal
# muc22968_TTTGTTGTCTAACGGT    basal prolif.
# muc22968_TTTGTTGTCTTGGAAC            basal
# Name: cell_type, Length: 254630, dtype: category
# Categories (13, object): ['?', 'PNEC', 'basal', 'basal prolif.', ..., 'ionocytes', 'suprabasal', 'tuft', 'viral']

# %%
# If the UMAP or any cell embeddings are already available in the `AnnData`, skip this command.
sc.tl.umap(adata)

# %%
sc.pl.umap(adata, color = ['cell_type', 'predicted_labels', 'majority_voting'], legend_loc = 'on data')

# %%
celltypist.dotplot(predictions, use_as_reference = 'cell_type', use_as_prediction = 'majority_voting')

# %%
#mkdir celltypist_covid
# Out:
# mkdir: cannot create directory ‘celltypist_covid’: File exists

# %%
top_3_genes = model.extract_top_markers("Plasma Cell", 3)
top_3_genes
# Out:
# array(['TNFSF11', 'LINC02245', 'WNT16'], dtype=object)

# %%
# Check expression of the three genes in the training set.
sc.pl.violin(adata_covid, top_3_genes, groupby = 'cell_type', rotation = 90)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Check expression of the three genes in the training set.
# ----> 2 sc.pl.violin(adata_covid, top_3_genes, groupby = 'cell_type', rotation = 90)
#
# File /usr/local/lib/python3.8/dist-packages/scanpy/plotting/_anndata.py:768, in violin(adata, keys, groupby, log, use_raw, stripplot, jitter, size, layer, scale, order, multi_panel, xlabel, ylabel, rotation, show, save, ax, **kwds)
#     762     raise ValueError(
#     763         f'Expected number of y-labels to be `{len(keys)}`, '
#     764         f'found `{len(ylabel)}`.'
#     765     )
#     767 if groupby is not None:
# --> 768     obs_df = get.obs_df(adata, keys=[groupby] + keys, layer=layer, use_raw=use_raw)
#     769     if kwds.get('palette', None) is None:
#     770         if not is_categorical_dtype(adata.obs[groupby]):
#
# File /usr/local/lib/python3.8/dist-packages/scanpy/get/get.py:276, in obs_df(adata, keys, obsm_keys, layer, gene_symbols, use_raw)
#     273 else:
#     274     alias_index = None
# --> 276 obs_cols, var_idx_keys, var_symbols = _check_indices(
#     277     adata.obs,
#     278     var.index,
#     279     "obs",
#     280     keys,
#     281     alias_index=alias_index,
#     282     use_raw=use_raw,
#     283 )
#     285 # Make df
#     286 df = pd.DataFrame(index=adata.obs_names)
#
# File /usr/local/lib/python3.8/dist-packages/scanpy/get/get.py:171, in _check_indices(dim_df, alt_index, dim, keys, alias_index, use_raw)
#     169         not_found.append(key)
#     170 if len(not_found) > 0:
# --> 171     raise KeyError(
#     172         f"Could not find keys '{not_found}' in columns of `adata.{dim}` or in"
#     173         f" {alt_repr}.{alt_search_repr}."
#     174     )
#     176 return col_keys, index_keys, index_aliases
#
# KeyError: "Could not find keys '['LINC02245']' in columns of `adata.obs` or in adata.var_names."

# %%
adata_covid.obs
# Out:
#                           identifier    patient             name  \
# muc21058_AAACCCAAGTTTGAGA   muc21058  patient_1  ALI_1_Barcode_1
# muc21058_AAACCCACACGCGCAT   muc21058  patient_1  ALI_1_Barcode_1
# muc21058_AAACCCACAGACACAG   muc21058  patient_1  ALI_1_Barcode_1
# muc21058_AAACCCAGTATTGCCA   muc21058  patient_1  ALI_1_Barcode_1
# muc21058_AAACCCAGTCGTATTG   muc21058  patient_1  ALI_1_Barcode_1
# ...                              ...        ...              ...
# muc22968_TTTGTTGCATCACCAA   muc22968  patient_4  ALI_3_Barcode_4
# muc22968_TTTGTTGGTTCCGTTC   muc22968  patient_4  ALI_3_Barcode_4
# muc22968_TTTGTTGTCCACACCT   muc22968  patient_4  ALI_3_Barcode_4
# muc22968_TTTGTTGTCTAACGGT   muc22968  patient_4  ALI_3_Barcode_4
# muc22968_TTTGTTGTCTTGGAAC   muc22968  patient_4  ALI_3_Barcode_4
#
#                           barcode_round sample  viral_counts  \
# muc21058_AAACCCAAGTTTGAGA         ALI_1      3           0.0
# muc21058_AAACCCACACGCGCAT         ALI_1      3           0.0
# muc21058_AAACCCACAGACACAG         ALI_1      3           0.0
# muc21058_AAACCCAGTATTGCCA         ALI_1      3           0.0
# muc21058_AAACCCAGTCGTATTG         ALI_1      3           0.0
# ...                                 ...    ...           ...
# muc22968_TTTGTTGCATCACCAA         ALI_3     11           0.0
# muc22968_TTTGTTGGTTCCGTTC         ALI_3     11           0.0
# muc22968_TTTGTTGTCCACACCT         ALI_3     11           0.0
# muc22968_TTTGTTGTCTAACGGT         ALI_3     11           0.0
# muc22968_TTTGTTGTCTTGGAAC         ALI_3     11           0.0
#
#                                     treatment            treatment_virus  \
# muc21058_AAACCCAAGTTTGAGA           TNFa_IFNg     TNFa_IFNg + sars-cov-2
# muc21058_AAACCCACACGCGCAT          IFNa (b_d)                 IFNa (b_d)
# muc21058_AAACCCACAGACACAG                IFNg                       IFNg
# muc21058_AAACCCAGTATTGCCA          IFNa (b_d)    IFNa (b_d) + sars-cov-2
# muc21058_AAACCCAGTCGTATTG        Tirapazamine  Tirapazamine + sars-cov-2
# ...                                       ...                        ...
# muc22968_TTTGTTGCATCACCAA           Sorafenib     Sorafenib + sars-cov-2
# muc22968_TTTGTTGGTTCCGTTC               TGFb2         TGFb2 + sars-cov-2
# muc22968_TTTGTTGTCCACACCT                DMSO          DMSO + sars-cov-2
# muc22968_TTTGTTGTCTAACGGT           Sorafenib     Sorafenib + sars-cov-2
# muc22968_TTTGTTGTCTTGGAAC  TGFb2_Tirapazamine          TGFb_Tirapazamine
#
#                           infected  n_counts  ...  _scvi_labels  \
# muc21058_AAACCCAAGTTTGAGA     True    9775.0  ...             0
# muc21058_AAACCCACACGCGCAT    False   12826.0  ...             0
# muc21058_AAACCCACAGACACAG    False   15557.0  ...             0
# muc21058_AAACCCAGTATTGCCA     True   15520.0  ...             0
# muc21058_AAACCCAGTCGTATTG     True   13483.0  ...             0
# ...                            ...       ...  ...           ...
# muc22968_TTTGTTGCATCACCAA     True   13844.0  ...             0
# muc22968_TTTGTTGGTTCCGTTC     True    2846.0  ...             0
# muc22968_TTTGTTGTCCACACCT     True   10235.0  ...             0
# muc22968_TTTGTTGTCTAACGGT     True   11320.0  ...             0
# muc22968_TTTGTTGTCTTGGAAC    False    6402.0  ...             0
#
#                            leiden_coarse  leiden_fine leiden_subset  \
# muc21058_AAACCCAAGTTTGAGA              3         13,1          13,1
# muc21058_AAACCCACACGCGCAT              4         14,0          14,0
# muc21058_AAACCCACAGACACAG              6           10            10
# muc21058_AAACCCAGTATTGCCA              4         14,0          14,0
# muc21058_AAACCCAGTCGTATTG              4         14,1          14,1
# ...                                  ...          ...           ...
# muc22968_TTTGTTGCATCACCAA              6           15            15
# muc22968_TTTGTTGGTTCCGTTC              6            2             2
# muc22968_TTTGTTGTCCACACCT              6            2             2
# muc22968_TTTGTTGTCTAACGGT             13           16            16
# muc22968_TTTGTTGTCTTGGAAC              0            6             6
#
#                               celltype_fine celltype_approx  \
# muc21058_AAACCCAAGTTTGAGA         sub5/club       13,1/club
# muc21058_AAACCCACACGCGCAT         sub3/club       14,0/club
# muc21058_AAACCCACAGACACAG     10/suprabasal   10/suprabasal
# muc21058_AAACCCAGTATTGCCA         sub3/club       14,0/club
# muc21058_AAACCCAGTCGTATTG         sub3/club       14,1/club
# ...                                     ...             ...
# muc22968_TTTGTTGCATCACCAA     15/suprabasal   15/suprabasal
# muc22968_TTTGTTGGTTCCGTTC      2/suprabasal    2/suprabasal
# muc22968_TTTGTTGTCCACACCT      2/suprabasal    2/suprabasal
# muc22968_TTTGTTGTCTAACGGT  16/basal prolif.   16/suprabasal
# muc22968_TTTGTTGTCTTGGAAC           6/basal         6/basal
#
#                                                 predicted_labels  \
# muc21058_AAACCCAAGTTTGAGA                               NK CD56+
# muc21058_AAACCCACACGCGCAT  Haematopoietic Progenitor CD34+/CD38-
# muc21058_AAACCCACAGACACAG  Haematopoietic Progenitor CD34+/CD38-
# muc21058_AAACCCAGTATTGCCA                        T CD4 Naive RTE
# muc21058_AAACCCAGTCGTATTG                             T CD8 EMRA
# ...                                                          ...
# muc22968_TTTGTTGCATCACCAA                               T G/D CM
# muc22968_TTTGTTGGTTCCGTTC                         Monocyte CD14+
# muc22968_TTTGTTGTCCACACCT                               T G/D CM
# muc22968_TTTGTTGTCTAACGGT                                  T MAI
# muc22968_TTTGTTGTCTTGGAAC                               T G/D CM
#
#                           over_clustering  \
# muc21058_AAACCCAAGTTTGAGA              18
# muc21058_AAACCCACACGCGCAT              54
# muc21058_AAACCCACAGACACAG              84
# muc21058_AAACCCAGTATTGCCA              27
# muc21058_AAACCCAGTCGTATTG              18
# ...                                   ...
# muc22968_TTTGTTGCATCACCAA             282
# muc22968_TTTGTTGGTTCCGTTC             332
# muc22968_TTTGTTGTCCACACCT             346
# muc22968_TTTGTTGTCTAACGGT              89
# muc22968_TTTGTTGTCTTGGAAC             283
#
#                                                  majority_voting  conf_score
# muc21058_AAACCCAAGTTTGAGA  Haematopoietic Progenitor CD34+/CD38-    0.126538
# muc21058_AAACCCACACGCGCAT  Haematopoietic Progenitor CD34+/CD38-    0.847628
# muc21058_AAACCCACAGACACAG                               T G/D CM    0.867448
# muc21058_AAACCCAGTATTGCCA  Haematopoietic Progenitor CD34+/CD38-    0.987700
# muc21058_AAACCCAGTCGTATTG  Haematopoietic Progenitor CD34+/CD38-    0.754063
# ...                                                          ...         ...
# muc22968_TTTGTTGCATCACCAA                               T G/D CM    0.979020
# muc22968_TTTGTTGGTTCCGTTC                               T G/D CM    0.538926
# muc22968_TTTGTTGTCCACACCT                               T G/D CM    0.992821
# muc22968_TTTGTTGTCTAACGGT                T Reg Activated Cycling    0.996122
# muc22968_TTTGTTGTCTTGGAAC                            Plasma Cell    0.996680
#
# [254630 rows x 30 columns]

# %%
# Check expression of the three genes in the query set.
# Here we use `majority_voting` from CellTypist as the cell type labels for this dataset.
sc.pl.violin(adata_covid, top_3_genes, groupby = 'majority_voting', rotation = 90)
